# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %cd /content/drive/Shared drives/IML Project/Project
data_path = '/content/drive/Shared drives/IML Project/Project/data/tfrecords_data'
project_path = '/content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool'

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import metrics

# %%
# %tensorflow_version 2.x

import tensorflow as tf

from tensorflow.keras import Sequential
from tensorflow.keras.models import load_model

from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Conv3D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import PReLU
from tensorflow.keras.layers import MaxPool3D, AveragePooling3D

from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import AveragePooling3D
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten

# %%
batch_size = 32

# %%
def decode(serialized_example):
    """
    Parses an image and label from the given `serialized_example`.
    It is used as a map function for `dataset.map`
    """

    features = tf.compat.v1.parse_single_example(
        serialized_example,
        features={
            'img_channels': tf.compat.v1.FixedLenFeature([], tf.int64),
            'img_height': tf.compat.v1.FixedLenFeature([], tf.int64),
            'img_width': tf.compat.v1.FixedLenFeature([], tf.int64),
            'img_raw': tf.compat.v1.FixedLenFeature([], tf.string),
            'sex': tf.compat.v1.FixedLenFeature([], tf.string),
            'age': tf.compat.v1.FixedLenFeature([], tf.float32),
            'label': tf.compat.v1.FixedLenFeature([], tf.string),
        })
    
    
    
    height = tf.cast(features['img_height'], tf.int32)
    width = tf.cast(features['img_width'], tf.int32)
    channels = tf.cast(features['img_channels'], tf.int32)
    image = tf.compat.v1.decode_raw(features['img_raw'], tf.float64)
    image = tf.reshape(image, (channels, height, width, 1))
    label = tf.compat.v1.decode_raw(features['label'], tf.float64)
    sex = tf.cast(features['sex'], tf.string)
    age = tf.cast(features['age'], tf.float32)
    return image, label

# %%
train_dataset = tf.data.TFRecordDataset(os.path.join(data_path, 'train.tfrecords'), compression_type='GZIP').map(decode).batch(batch_size)
val_dataset = tf.data.TFRecordDataset(os.path.join(data_path, 'validation.tfrecords'), compression_type='GZIP').map(decode).batch(batch_size)

# %%
def create_model():
    kernel_regularizer = tf.keras.regularizers.l2(0.001)
    he_normal = tf.keras.initializers.he_normal(seed=0)
    lecun_normal = tf.keras.initializers.lecun_normal(seed=0)

    input_3d = (62, 96, 96, 1)
    pool_3d = (2, 2, 2)

    model = Sequential()
    
    model.add(tf.keras.layers.InputLayer(input_shape=input_3d))
    model.add(Conv3D(filters=8,
                     kernel_size=3,
                     kernel_regularizer=kernel_regularizer,
                     kernel_initializer=he_normal))
    model.add(BatchNormalization())
    model.add(LeakyReLU())
    model.add(AveragePooling3D(pool_size=pool_3d, strides=None, padding='valid', data_format=None))

    model.add(Conv3D(filters=8,
                     kernel_size=3,
                     kernel_regularizer=kernel_regularizer,
                     kernel_initializer=he_normal))
    model.add(BatchNormalization())
    model.add(LeakyReLU())
    model.add(AveragePooling3D(pool_size=pool_3d, strides=None, padding='valid', data_format=None))

    model.add(Conv3D(filters=8,
                     kernel_size=3,
                     kernel_regularizer=kernel_regularizer,
                     kernel_initializer=he_normal))
    model.add(BatchNormalization())
    model.add(LeakyReLU())
    model.add(AveragePooling3D(pool_size=pool_3d, strides=None, padding='valid', data_format=None))

    model.add(Flatten())
    model.add(Dense(1024, name='dense1', kernel_regularizer=kernel_regularizer, kernel_initializer=he_normal))
    model.add(LeakyReLU())
    model.add(Dropout(0.5, name='dropout1'))

    model.add(Dense(512, activation='relu', name='dense2', kernel_regularizer=kernel_regularizer, kernel_initializer=he_normal))
    model.add(LeakyReLU())
    model.add(Dropout(0.5, name='dropout2'))

    model.add(Dense(3, activation='softmax', name='softmax', kernel_initializer=lecun_normal))

    model.compile(loss='categorical_crossentropy',
                  optimizer=tf.keras.optimizers.Adam(1e-5),
                  metrics=[tf.keras.metrics.CategoricalAccuracy()])

    return model

# %%
reducelr_callback = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_categorical_accuracy',
                                                         factor=0.2,
                                                         patience=5,
                                                         min_delta=0.01,
                                                         verbose=1)
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(os.path.join(project_path, 'checkpoints', 'cp.ckpt'),
                                                         monitor='val_categorical_accuracy',
                                                         verbose=1,
                                                         save_best_only=True,
                                                         mode='max')
weights_callback = tf.keras.callbacks.ModelCheckpoint(os.path.join(project_path, 'weights', 'best_weights.h5'),
                                                      monitor='val_categorical_accuracy',
                                                      verbose=1,
                                                      save_best_only=True,
                                                      save_weights_only=True,
                                                      mode='max')

callbacks_list = [weights_callback, checkpoint_callback, reducelr_callback]

# %%
model = create_model()
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_4 (Conv3D)            (None, 60, 94, 94, 8)     224
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 60, 94, 94, 8)     32
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 60, 94, 94, 8)     0
# _________________________________________________________________
# average_pooling3d_3 (Average (None, 30, 47, 47, 8)     0
# _________________________________________________________________
# conv3d_5 (Conv3D)            (None, 28, 45, 45, 8)     1736
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 28, 45, 45, 8)     32
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 28, 45, 45, 8)     0
# _________________________________________________________________
# average_pooling3d_4 (Average (None, 14, 22, 22, 8)     0
# _________________________________________________________________
# conv3d_6 (Conv3D)            (None, 12, 20, 20, 8)     1736
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 12, 20, 20, 8)     32
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 12, 20, 20, 8)     0
# _________________________________________________________________
# average_pooling3d_5 (Average (None, 6, 10, 10, 8)      0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4800)              0
# _________________________________________________________________
# dense1 (Dense)               (None, 1024)              4916224
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 1024)              0
# _________________________________________________________________
# dropout1 (Dropout)           (None, 1024)              0
# _________________________________________________________________
# dense2 (Dense)               (None, 512)               524800
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (None, 512)               0
# _________________________________________________________________
# dropout2 (Dropout)           (None, 512)               0
# _________________________________________________________________
# softmax (Dense)              (None, 3)                 1539
# =================================================================
# Total params: 5,446,355
# Trainable params: 5,446,307
# Non-trainable params: 48
# _________________________________________________________________

# %%
if os.path.exists(os.path.join(project_path, 'checkpoints', 'cp.ckpt')):
    model = load_model(os.path.join(project_path, 'checkpoints', 'cp.ckpt'))

# %%
history = model.fit(train_dataset, validation_data=val_dataset, epochs=75, callbacks=callbacks_list, verbose=1)
# Out:
# Epoch 1/75
#      66/Unknown - 76s 1s/step - loss: 4.2600 - categorical_accuracy: 0.4211
# Epoch 00001: val_categorical_accuracy improved from 0.30115 to 0.30345, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/weights/best_weights.h5
#
# Epoch 00001: val_categorical_accuracy improved from 0.30115 to 0.30345, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt
# INFO:tensorflow:Assets written to: /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt/assets
# 66/66 [==============================] - 101s 2s/step - loss: 4.2600 - categorical_accuracy: 0.4211 - val_loss: 4.2844 - val_categorical_accuracy: 0.3034 - lr: 1.0000e-05
# Epoch 2/75
# 66/66 [==============================] - ETA: 0s - loss: 4.1750 - categorical_accuracy: 0.4689
# Epoch 00002: val_categorical_accuracy improved from 0.30345 to 0.33103, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/weights/best_weights.h5
#
# Epoch 00002: val_categorical_accuracy improved from 0.30345 to 0.33103, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt
# INFO:tensorflow:Assets written to: /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt/assets
# 66/66 [==============================] - 97s 1s/step - loss: 4.1750 - categorical_accuracy: 0.4689 - val_loss: 4.2610 - val_categorical_accuracy: 0.3310 - lr: 1.0000e-05
# Epoch 3/75
# 66/66 [==============================] - ETA: 0s - loss: 4.1291 - categorical_accuracy: 0.4917
# Epoch 00003: val_categorical_accuracy improved from 0.33103 to 0.35172, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/weights/best_weights.h5
#
# Epoch 00003: val_categorical_accuracy improved from 0.33103 to 0.35172, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt
# INFO:tensorflow:Assets written to: /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt/assets
# 66/66 [==============================] - 83s 1s/step - loss: 4.1291 - categorical_accuracy: 0.4917 - val_loss: 4.2614 - val_categorical_accuracy: 0.3517 - lr: 1.0000e-05
# Epoch 4/75
# 66/66 [==============================] - ETA: 0s - loss: 4.0811 - categorical_accuracy: 0.5187
# Epoch 00004: val_categorical_accuracy improved from 0.35172 to 0.39540, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/weights/best_weights.h5
#
# Epoch 00004: val_categorical_accuracy improved from 0.35172 to 0.39540, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt
# INFO:tensorflow:Assets written to: /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt/assets
# 66/66 [==============================] - 75s 1s/step - loss: 4.0811 - categorical_accuracy: 0.5187 - val_loss: 4.2264 - val_categorical_accuracy: 0.3954 - lr: 1.0000e-05
# Epoch 5/75
# 66/66 [==============================] - ETA: 0s - loss: 4.0644 - categorical_accuracy: 0.5211
# Epoch 00005: val_categorical_accuracy improved from 0.39540 to 0.41149, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/weights/best_weights.h5
#
# Epoch 00005: val_categorical_accuracy improved from 0.39540 to 0.41149, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt
# INFO:tensorflow:Assets written to: /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt/assets
# 66/66 [==============================] - 71s 1s/step - loss: 4.0644 - categorical_accuracy: 0.5211 - val_loss: 4.2056 - val_categorical_accuracy: 0.4115 - lr: 1.0000e-05
# Epoch 6/75
# 66/66 [==============================] - ETA: 0s - loss: 4.0238 - categorical_accuracy: 0.5514
# Epoch 00006: val_categorical_accuracy improved from 0.41149 to 0.41839, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/weights/best_weights.h5
#
# Epoch 00006: val_categorical_accuracy improved from 0.41149 to 0.41839, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt
# INFO:tensorflow:Assets written to: /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt/assets
# 66/66 [==============================] - 72s 1s/step - loss: 4.0238 - categorical_accuracy: 0.5514 - val_loss: 4.1854 - val_categorical_accuracy: 0.4184 - lr: 1.0000e-05
# Epoch 7/75
# 66/66 [==============================] - ETA: 0s - loss: 4.0034 - categorical_accuracy: 0.5695
# Epoch 00007: val_categorical_accuracy improved from 0.41839 to 0.42989, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/weights/best_weights.h5
#
# Epoch 00007: val_categorical_accuracy improved from 0.41839 to 0.42989, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt
# INFO:tensorflow:Assets written to: /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt/assets
# 66/66 [==============================] - 71s 1s/step - loss: 4.0034 - categorical_accuracy: 0.5695 - val_loss: 4.1694 - val_categorical_accuracy: 0.4299 - lr: 1.0000e-05
# Epoch 8/75
# 66/66 [==============================] - ETA: 0s - loss: 3.9790 - categorical_accuracy: 0.5775
# Epoch 00008: val_categorical_accuracy improved from 0.42989 to 0.44598, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/weights/best_weights.h5
#
# Epoch 00008: val_categorical_accuracy improved from 0.42989 to 0.44598, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt
# INFO:tensorflow:Assets written to: /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt/assets
# 66/66 [==============================] - 73s 1s/step - loss: 3.9790 - categorical_accuracy: 0.5775 - val_loss: 4.1441 - val_categorical_accuracy: 0.4460 - lr: 1.0000e-05
# Epoch 9/75
# 66/66 [==============================] - ETA: 0s - loss: 3.9402 - categorical_accuracy: 0.5946
# Epoch 00009: val_categorical_accuracy improved from 0.44598 to 0.45747, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/weights/best_weights.h5
#
# Epoch 00009: val_categorical_accuracy improved from 0.44598 to 0.45747, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt
# INFO:tensorflow:Assets written to: /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt/assets
# 66/66 [==============================] - 71s 1s/step - loss: 3.9402 - categorical_accuracy: 0.5946 - val_loss: 4.1290 - val_categorical_accuracy: 0.4575 - lr: 1.0000e-05
# Epoch 10/75
# 66/66 [==============================] - ETA: 0s - loss: 3.9119 - categorical_accuracy: 0.6159
# Epoch 00010: val_categorical_accuracy improved from 0.45747 to 0.46207, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/weights/best_weights.h5
#
# Epoch 00010: val_categorical_accuracy improved from 0.45747 to 0.46207, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt
# INFO:tensorflow:Assets written to: /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt/assets
# 66/66 [==============================] - 72s 1s/step - loss: 3.9119 - categorical_accuracy: 0.6159 - val_loss: 4.1029 - val_categorical_accuracy: 0.4621 - lr: 1.0000e-05
# Epoch 11/75
# 66/66 [==============================] - ETA: 0s - loss: 3.8939 - categorical_accuracy: 0.6363
# Epoch 00011: val_categorical_accuracy improved from 0.46207 to 0.47356, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/weights/best_weights.h5
#
# Epoch 00011: val_categorical_accuracy improved from 0.46207 to 0.47356, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt
# INFO:tensorflow:Assets written to: /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt/assets
# 66/66 [==============================] - 71s 1s/step - loss: 3.8939 - categorical_accuracy: 0.6363 - val_loss: 4.0683 - val_categorical_accuracy: 0.4736 - lr: 1.0000e-05
# Epoch 12/75
# 66/66 [==============================] - ETA: 0s - loss: 3.8656 - categorical_accuracy: 0.6264
# Epoch 00012: val_categorical_accuracy improved from 0.47356 to 0.47586, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/weights/best_weights.h5
#
# Epoch 00012: val_categorical_accuracy improved from 0.47356 to 0.47586, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt
# INFO:tensorflow:Assets written to: /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt/assets
# 66/66 [==============================] - 71s 1s/step - loss: 3.8656 - categorical_accuracy: 0.6264 - val_loss: 4.0383 - val_categorical_accuracy: 0.4759 - lr: 1.0000e-05
# Epoch 13/75
# 66/66 [==============================] - ETA: 0s - loss: 3.8395 - categorical_accuracy: 0.6524
# Epoch 00013: val_categorical_accuracy improved from 0.47586 to 0.50345, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/weights/best_weights.h5
#
# Epoch 00013: val_categorical_accuracy improved from 0.47586 to 0.50345, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt
# INFO:tensorflow:Assets written to: /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt/assets
# 66/66 [==============================] - 72s 1s/step - loss: 3.8395 - categorical_accuracy: 0.6524 - val_loss: 4.0270 - val_categorical_accuracy: 0.5034 - lr: 1.0000e-05
# Epoch 14/75
# 66/66 [==============================] - ETA: 0s - loss: 3.8088 - categorical_accuracy: 0.6586
# Epoch 00014: val_categorical_accuracy improved from 0.50345 to 0.53333, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/weights/best_weights.h5
#
# Epoch 00014: val_categorical_accuracy improved from 0.50345 to 0.53333, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt
# INFO:tensorflow:Assets written to: /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt/assets
# 66/66 [==============================] - 70s 1s/step - loss: 3.8088 - categorical_accuracy: 0.6586 - val_loss: 4.0050 - val_categorical_accuracy: 0.5333 - lr: 1.0000e-05
# Epoch 15/75
# 66/66 [==============================] - ETA: 0s - loss: 3.7714 - categorical_accuracy: 0.6961
# Epoch 00015: val_categorical_accuracy improved from 0.53333 to 0.53563, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/weights/best_weights.h5
#
# Epoch 00015: val_categorical_accuracy improved from 0.53333 to 0.53563, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt
# INFO:tensorflow:Assets written to: /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt/assets
# 66/66 [==============================] - 70s 1s/step - loss: 3.7714 - categorical_accuracy: 0.6961 - val_loss: 3.9861 - val_categorical_accuracy: 0.5356 - lr: 1.0000e-05
# Epoch 16/75
# 66/66 [==============================] - ETA: 0s - loss: 3.7486 - categorical_accuracy: 0.6923
# Epoch 00016: val_categorical_accuracy improved from 0.53563 to 0.54713, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/weights/best_weights.h5
#
# Epoch 00016: val_categorical_accuracy improved from 0.53563 to 0.54713, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt
# INFO:tensorflow:Assets written to: /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt/assets
# 66/66 [==============================] - 71s 1s/step - loss: 3.7486 - categorical_accuracy: 0.6923 - val_loss: 3.9803 - val_categorical_accuracy: 0.5471 - lr: 1.0000e-05
# Epoch 17/75
# 66/66 [==============================] - ETA: 0s - loss: 3.7088 - categorical_accuracy: 0.7122
# Epoch 00017: val_categorical_accuracy improved from 0.54713 to 0.55632, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/weights/best_weights.h5
#
# Epoch 00017: val_categorical_accuracy improved from 0.54713 to 0.55632, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt
# INFO:tensorflow:Assets written to: /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt/assets
# 66/66 [==============================] - 71s 1s/step - loss: 3.7088 - categorical_accuracy: 0.7122 - val_loss: 3.9596 - val_categorical_accuracy: 0.5563 - lr: 1.0000e-05
# Epoch 18/75
# 66/66 [==============================] - ETA: 0s - loss: 3.6954 - categorical_accuracy: 0.7098
# Epoch 00018: val_categorical_accuracy improved from 0.55632 to 0.56322, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/weights/best_weights.h5
#
# Epoch 00018: val_categorical_accuracy improved from 0.55632 to 0.56322, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt
# INFO:tensorflow:Assets written to: /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt/assets
# 66/66 [==============================] - 72s 1s/step - loss: 3.6954 - categorical_accuracy: 0.7098 - val_loss: 3.9333 - val_categorical_accuracy: 0.5632 - lr: 1.0000e-05
# Epoch 19/75
# 66/66 [==============================] - ETA: 0s - loss: 3.6653 - categorical_accuracy: 0.7245
# Epoch 00019: val_categorical_accuracy improved from 0.56322 to 0.57701, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/weights/best_weights.h5
#
# Epoch 00019: val_categorical_accuracy improved from 0.56322 to 0.57701, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt
# INFO:tensorflow:Assets written to: /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt/assets
# 66/66 [==============================] - 71s 1s/step - loss: 3.6653 - categorical_accuracy: 0.7245 - val_loss: 3.9141 - val_categorical_accuracy: 0.5770 - lr: 1.0000e-05
# Epoch 20/75
# 66/66 [==============================] - ETA: 0s - loss: 3.6506 - categorical_accuracy: 0.7302
# Epoch 00020: val_categorical_accuracy improved from 0.57701 to 0.59540, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/weights/best_weights.h5
#
# Epoch 00020: val_categorical_accuracy improved from 0.57701 to 0.59540, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt
# INFO:tensorflow:Assets written to: /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt/assets
# 66/66 [==============================] - 71s 1s/step - loss: 3.6506 - categorical_accuracy: 0.7302 - val_loss: 3.8899 - val_categorical_accuracy: 0.5954 - lr: 1.0000e-05
# Epoch 21/75
# 66/66 [==============================] - ETA: 0s - loss: 3.6207 - categorical_accuracy: 0.7511
# Epoch 00021: val_categorical_accuracy did not improve from 0.59540
#
# Epoch 00021: val_categorical_accuracy did not improve from 0.59540
# 66/66 [==============================] - 67s 1s/step - loss: 3.6207 - categorical_accuracy: 0.7511 - val_loss: 3.9146 - val_categorical_accuracy: 0.5793 - lr: 1.0000e-05
# Epoch 22/75
# 66/66 [==============================] - ETA: 0s - loss: 3.5955 - categorical_accuracy: 0.7648
# Epoch 00022: val_categorical_accuracy improved from 0.59540 to 0.59770, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/weights/best_weights.h5
#
# Epoch 00022: val_categorical_accuracy improved from 0.59540 to 0.59770, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt
# INFO:tensorflow:Assets written to: /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt/assets
# 66/66 [==============================] - 70s 1s/step - loss: 3.5955 - categorical_accuracy: 0.7648 - val_loss: 3.8748 - val_categorical_accuracy: 0.5977 - lr: 1.0000e-05
# Epoch 23/75
# 66/66 [==============================] - ETA: 0s - loss: 3.5632 - categorical_accuracy: 0.7738
# Epoch 00023: val_categorical_accuracy did not improve from 0.59770
#
# Epoch 00023: val_categorical_accuracy did not improve from 0.59770
# 66/66 [==============================] - 66s 1s/step - loss: 3.5632 - categorical_accuracy: 0.7738 - val_loss: 3.8596 - val_categorical_accuracy: 0.5908 - lr: 1.0000e-05
# Epoch 24/75
# 66/66 [==============================] - ETA: 0s - loss: 3.5477 - categorical_accuracy: 0.7786
# Epoch 00024: val_categorical_accuracy improved from 0.59770 to 0.60230, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/weights/best_weights.h5
#
# Epoch 00024: val_categorical_accuracy improved from 0.59770 to 0.60230, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt
# INFO:tensorflow:Assets written to: /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt/assets
# 66/66 [==============================] - 68s 1s/step - loss: 3.5477 - categorical_accuracy: 0.7786 - val_loss: 3.8382 - val_categorical_accuracy: 0.6023 - lr: 1.0000e-05
# Epoch 25/75
# 66/66 [==============================] - ETA: 0s - loss: 3.5319 - categorical_accuracy: 0.7795
# Epoch 00025: val_categorical_accuracy improved from 0.60230 to 0.60460, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/weights/best_weights.h5
#
# Epoch 00025: val_categorical_accuracy improved from 0.60230 to 0.60460, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt
# INFO:tensorflow:Assets written to: /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt/assets
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 1.9999999494757505e-06.
# 66/66 [==============================] - 71s 1s/step - loss: 3.5319 - categorical_accuracy: 0.7795 - val_loss: 3.8170 - val_categorical_accuracy: 0.6046 - lr: 1.0000e-05
# Epoch 26/75
# 66/66 [==============================] - ETA: 0s - loss: 3.5131 - categorical_accuracy: 0.7999
# Epoch 00026: val_categorical_accuracy improved from 0.60460 to 0.62069, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/weights/best_weights.h5
#
# Epoch 00026: val_categorical_accuracy improved from 0.60460 to 0.62069, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt
# INFO:tensorflow:Assets written to: /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt/assets
# 66/66 [==============================] - 69s 1s/step - loss: 3.5131 - categorical_accuracy: 0.7999 - val_loss: 3.7823 - val_categorical_accuracy: 0.6207 - lr: 2.0000e-06
# Epoch 27/75
# 66/66 [==============================] - ETA: 0s - loss: 3.5101 - categorical_accuracy: 0.7966
# Epoch 00027: val_categorical_accuracy did not improve from 0.62069
#
# Epoch 00027: val_categorical_accuracy did not improve from 0.62069
# 66/66 [==============================] - 66s 1s/step - loss: 3.5101 - categorical_accuracy: 0.7966 - val_loss: 3.7837 - val_categorical_accuracy: 0.6207 - lr: 2.0000e-06
# Epoch 28/75
# 66/66 [==============================] - ETA: 0s - loss: 3.4963 - categorical_accuracy: 0.8004
# Epoch 00028: val_categorical_accuracy improved from 0.62069 to 0.62299, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/weights/best_weights.h5
#
# Epoch 00028: val_categorical_accuracy improved from 0.62069 to 0.62299, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt
# INFO:tensorflow:Assets written to: /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt/assets
# 66/66 [==============================] - 69s 1s/step - loss: 3.4963 - categorical_accuracy: 0.8004 - val_loss: 3.7796 - val_categorical_accuracy: 0.6230 - lr: 2.0000e-06
# Epoch 29/75
# 66/66 [==============================] - ETA: 0s - loss: 3.4846 - categorical_accuracy: 0.8084
# Epoch 00029: val_categorical_accuracy did not improve from 0.62299
#
# Epoch 00029: val_categorical_accuracy did not improve from 0.62299
# 66/66 [==============================] - 66s 996ms/step - loss: 3.4846 - categorical_accuracy: 0.8084 - val_loss: 3.7762 - val_categorical_accuracy: 0.6184 - lr: 2.0000e-06
# Epoch 30/75
# 66/66 [==============================] - ETA: 0s - loss: 3.4870 - categorical_accuracy: 0.8099
# Epoch 00030: val_categorical_accuracy did not improve from 0.62299
#
# Epoch 00030: val_categorical_accuracy did not improve from 0.62299
# 66/66 [==============================] - 63s 960ms/step - loss: 3.4870 - categorical_accuracy: 0.8099 - val_loss: 3.7765 - val_categorical_accuracy: 0.6230 - lr: 2.0000e-06
# Epoch 31/75
# 66/66 [==============================] - ETA: 0s - loss: 3.4777 - categorical_accuracy: 0.8099
# Epoch 00031: val_categorical_accuracy improved from 0.62299 to 0.63908, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/weights/best_weights.h5
#
# Epoch 00031: val_categorical_accuracy improved from 0.62299 to 0.63908, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt
# INFO:tensorflow:Assets written to: /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt/assets
# 66/66 [==============================] - 67s 1s/step - loss: 3.4777 - categorical_accuracy: 0.8099 - val_loss: 3.7632 - val_categorical_accuracy: 0.6391 - lr: 2.0000e-06
# Epoch 32/75
# 66/66 [==============================] - ETA: 0s - loss: 3.4725 - categorical_accuracy: 0.8113
# Epoch 00032: val_categorical_accuracy improved from 0.63908 to 0.65057, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/weights/best_weights.h5
#
# Epoch 00032: val_categorical_accuracy improved from 0.63908 to 0.65057, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt
# INFO:tensorflow:Assets written to: /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt/assets
# 66/66 [==============================] - 68s 1s/step - loss: 3.4725 - categorical_accuracy: 0.8113 - val_loss: 3.7522 - val_categorical_accuracy: 0.6506 - lr: 2.0000e-06
# Epoch 33/75
# 66/66 [==============================] - ETA: 0s - loss: 3.4669 - categorical_accuracy: 0.8160
# Epoch 00033: val_categorical_accuracy did not improve from 0.65057
#
# Epoch 00033: val_categorical_accuracy did not improve from 0.65057
# 66/66 [==============================] - 67s 1s/step - loss: 3.4669 - categorical_accuracy: 0.8160 - val_loss: 3.7524 - val_categorical_accuracy: 0.6483 - lr: 2.0000e-06
# Epoch 34/75
# 66/66 [==============================] - ETA: 0s - loss: 3.4651 - categorical_accuracy: 0.8108
# Epoch 00034: val_categorical_accuracy did not improve from 0.65057
#
# Epoch 00034: val_categorical_accuracy did not improve from 0.65057
# 66/66 [==============================] - 64s 964ms/step - loss: 3.4651 - categorical_accuracy: 0.8108 - val_loss: 3.7563 - val_categorical_accuracy: 0.6345 - lr: 2.0000e-06
# Epoch 35/75
# 66/66 [==============================] - ETA: 0s - loss: 3.4620 - categorical_accuracy: 0.8113
# Epoch 00035: val_categorical_accuracy improved from 0.65057 to 0.65287, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/weights/best_weights.h5
#
# Epoch 00035: val_categorical_accuracy improved from 0.65057 to 0.65287, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt
# INFO:tensorflow:Assets written to: /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt/assets
# 66/66 [==============================] - 67s 1s/step - loss: 3.4620 - categorical_accuracy: 0.8113 - val_loss: 3.7472 - val_categorical_accuracy: 0.6529 - lr: 2.0000e-06
# Epoch 36/75
# 66/66 [==============================] - ETA: 0s - loss: 3.4441 - categorical_accuracy: 0.8170
# Epoch 00036: val_categorical_accuracy improved from 0.65287 to 0.66437, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/weights/best_weights.h5
#
# Epoch 00036: val_categorical_accuracy improved from 0.65287 to 0.66437, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt
# INFO:tensorflow:Assets written to: /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt/assets
# 66/66 [==============================] - 69s 1s/step - loss: 3.4441 - categorical_accuracy: 0.8170 - val_loss: 3.7420 - val_categorical_accuracy: 0.6644 - lr: 2.0000e-06
# Epoch 37/75
# 66/66 [==============================] - ETA: 0s - loss: 3.4459 - categorical_accuracy: 0.8274
# Epoch 00037: val_categorical_accuracy did not improve from 0.66437
#
# Epoch 00037: val_categorical_accuracy did not improve from 0.66437
# 66/66 [==============================] - 65s 983ms/step - loss: 3.4459 - categorical_accuracy: 0.8274 - val_loss: 3.7334 - val_categorical_accuracy: 0.6621 - lr: 2.0000e-06
# Epoch 38/75
# 66/66 [==============================] - ETA: 0s - loss: 3.4467 - categorical_accuracy: 0.8212
# Epoch 00038: val_categorical_accuracy improved from 0.66437 to 0.67126, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/weights/best_weights.h5
#
# Epoch 00038: val_categorical_accuracy improved from 0.66437 to 0.67126, saving model to /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt
# INFO:tensorflow:Assets written to: /content/drive/Shared drives/IML Project/Project/baseline_LR_AvgPool/checkpoints/cp.ckpt/assets
# 66/66 [==============================] - 70s 1s/step - loss: 3.4467 - categorical_accuracy: 0.8212 - val_loss: 3.7225 - val_categorical_accuracy: 0.6713 - lr: 2.0000e-06
# Epoch 39/75
# 66/66 [==============================] - ETA: 0s - loss: 3.4457 - categorical_accuracy: 0.8231
# Epoch 00039: val_categorical_accuracy did not improve from 0.67126
#
# Epoch 00039: val_categorical_accuracy did not improve from 0.67126
# 66/66 [==============================] - 65s 980ms/step - loss: 3.4457 - categorical_accuracy: 0.8231 - val_loss: 3.7337 - val_categorical_accuracy: 0.6552 - lr: 2.0000e-06
# Epoch 40/75
# 66/66 [==============================] - ETA: 0s - loss: 3.4396 - categorical_accuracy: 0.8236
# Epoch 00040: val_categorical_accuracy did not improve from 0.67126
#
# Epoch 00040: val_categorical_accuracy did not improve from 0.67126
# 66/66 [==============================] - 64s 962ms/step - loss: 3.4396 - categorical_accuracy: 0.8236 - val_loss: 3.7216 - val_categorical_accuracy: 0.6667 - lr: 2.0000e-06
# Epoch 41/75
# 66/66 [==============================] - ETA: 0s - loss: 3.4432 - categorical_accuracy: 0.8146
# Epoch 00041: val_categorical_accuracy did not improve from 0.67126
#
# Epoch 00041: val_categorical_accuracy did not improve from 0.67126
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 3.999999989900971e-07.
# 66/66 [==============================] - 63s 958ms/step - loss: 3.4432 - categorical_accuracy: 0.8146 - val_loss: 3.7231 - val_categorical_accuracy: 0.6644 - lr: 2.0000e-06
# Epoch 42/75
# 66/66 [==============================] - ETA: 0s - loss: 3.4241 - categorical_accuracy: 0.8298
# Epoch 00042: val_categorical_accuracy did not improve from 0.67126
#
# Epoch 00042: val_categorical_accuracy did not improve from 0.67126
# 66/66 [==============================] - 64s 963ms/step - loss: 3.4241 - categorical_accuracy: 0.8298 - val_loss: 3.7212 - val_categorical_accuracy: 0.6667 - lr: 4.0000e-07
# Epoch 43/75
# 66/66 [==============================] - ETA: 0s - loss: 3.4304 - categorical_accuracy: 0.8094
# Epoch 00043: val_categorical_accuracy did not improve from 0.67126
#
# Epoch 00043: val_categorical_accuracy did not improve from 0.67126
# 66/66 [==============================] - 65s 980ms/step - loss: 3.4304 - categorical_accuracy: 0.8094 - val_loss: 3.7196 - val_categorical_accuracy: 0.6644 - lr: 4.0000e-07
# Epoch 44/75
# 66/66 [==============================] - ETA: 0s - loss: 3.4373 - categorical_accuracy: 0.8265
# Epoch 00044: val_categorical_accuracy did not improve from 0.67126
#
# Epoch 00044: val_categorical_accuracy did not improve from 0.67126
# 66/66 [==============================] - 63s 958ms/step - loss: 3.4373 - categorical_accuracy: 0.8265 - val_loss: 3.7215 - val_categorical_accuracy: 0.6598 - lr: 4.0000e-07
# Epoch 45/75
# 66/66 [==============================] - ETA: 0s - loss: 3.4250 - categorical_accuracy: 0.8265
# Epoch 00045: val_categorical_accuracy did not improve from 0.67126
#
# Epoch 00045: val_categorical_accuracy did not improve from 0.67126
# 66/66 [==============================] - 63s 957ms/step - loss: 3.4250 - categorical_accuracy: 0.8265 - val_loss: 3.7154 - val_categorical_accuracy: 0.6644 - lr: 4.0000e-07
# Epoch 46/75
# 66/66 [==============================] - ETA: 0s - loss: 3.4226 - categorical_accuracy: 0.8303
# Epoch 00046: val_categorical_accuracy did not improve from 0.67126
#
# Epoch 00046: val_categorical_accuracy did not improve from 0.67126
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 8.00000009348878e-08.
# 66/66 [==============================] - 63s 956ms/step - loss: 3.4226 - categorical_accuracy: 0.8303 - val_loss: 3.7168 - val_categorical_accuracy: 0.6667 - lr: 4.0000e-07
# Epoch 47/75
# 66/66 [==============================] - ETA: 0s - loss: 3.4293 - categorical_accuracy: 0.8212
# Epoch 00047: val_categorical_accuracy did not improve from 0.67126
#
# Epoch 00047: val_categorical_accuracy did not improve from 0.67126
# 66/66 [==============================] - 64s 963ms/step - loss: 3.4293 - categorical_accuracy: 0.8212 - val_loss: 3.7172 - val_categorical_accuracy: 0.6667 - lr: 8.0000e-08
# Epoch 48/75
# 66/66 [==============================] - ETA: 0s - loss: 3.4180 - categorical_accuracy: 0.8359
# Epoch 00048: val_categorical_accuracy did not improve from 0.67126
#
# Epoch 00048: val_categorical_accuracy did not improve from 0.67126
# 66/66 [==============================] - 64s 969ms/step - loss: 3.4180 - categorical_accuracy: 0.8359 - val_loss: 3.7181 - val_categorical_accuracy: 0.6621 - lr: 8.0000e-08
# Epoch 49/75
# 66/66 [==============================] - ETA: 0s - loss: 3.4157 - categorical_accuracy: 0.8359
# Epoch 00049: val_categorical_accuracy did not improve from 0.67126
#
# Epoch 00049: val_categorical_accuracy did not improve from 0.67126
# 66/66 [==============================] - 63s 961ms/step - loss: 3.4157 - categorical_accuracy: 0.8359 - val_loss: 3.7191 - val_categorical_accuracy: 0.6621 - lr: 8.0000e-08
# Epoch 50/75
# 66/66 [==============================] - ETA: 0s - loss: 3.4201 - categorical_accuracy: 0.8331
# Epoch 00050: val_categorical_accuracy did not improve from 0.67126
#
# Epoch 00050: val_categorical_accuracy did not improve from 0.67126
# 66/66 [==============================] - 63s 956ms/step - loss: 3.4201 - categorical_accuracy: 0.8331 - val_loss: 3.7193 - val_categorical_accuracy: 0.6621 - lr: 8.0000e-08
# Epoch 51/75
# 66/66 [==============================] - ETA: 0s - loss: 3.4296 - categorical_accuracy: 0.8193
# Epoch 00051: val_categorical_accuracy did not improve from 0.67126
#
# Epoch 00051: val_categorical_accuracy did not improve from 0.67126
#
# Epoch 00051: ReduceLROnPlateau reducing learning rate to 1.5999999902760466e-08.
# 66/66 [==============================] - 63s 959ms/step - loss: 3.4296 - categorical_accuracy: 0.8193 - val_loss: 3.7186 - val_categorical_accuracy: 0.6621 - lr: 8.0000e-08
# Epoch 52/75
# 66/66 [==============================] - ETA: 0s - loss: 3.4267 - categorical_accuracy: 0.8331
# Epoch 00052: val_categorical_accuracy did not improve from 0.67126
#
# Epoch 00052: val_categorical_accuracy did not improve from 0.67126
# 66/66 [==============================] - 64s 974ms/step - loss: 3.4267 - categorical_accuracy: 0.8331 - val_loss: 3.7187 - val_categorical_accuracy: 0.6621 - lr: 1.6000e-08
# Epoch 53/75
# 66/66 [==============================] - ETA: 0s - loss: 3.4271 - categorical_accuracy: 0.8250
# Epoch 00053: val_categorical_accuracy did not improve from 0.67126
#
# Epoch 00053: val_categorical_accuracy did not improve from 0.67126
# 66/66 [==============================] - 64s 968ms/step - loss: 3.4271 - categorical_accuracy: 0.8250 - val_loss: 3.7187 - val_categorical_accuracy: 0.6621 - lr: 1.6000e-08
# Epoch 54/75
# 66/66 [==============================] - ETA: 0s - loss: 3.4196 - categorical_accuracy: 0.8284
# Epoch 00054: val_categorical_accuracy did not improve from 0.67126
#
# Epoch 00054: val_categorical_accuracy did not improve from 0.67126
# 66/66 [==============================] - 66s 1s/step - loss: 3.4196 - categorical_accuracy: 0.8284 - val_loss: 3.7186 - val_categorical_accuracy: 0.6621 - lr: 1.6000e-08
# Epoch 55/75
# 66/66 [==============================] - ETA: 0s - loss: 3.4259 - categorical_accuracy: 0.8151
# Epoch 00055: val_categorical_accuracy did not improve from 0.67126
#
# Epoch 00055: val_categorical_accuracy did not improve from 0.67126
# 66/66 [==============================] - 64s 971ms/step - loss: 3.4259 - categorical_accuracy: 0.8151 - val_loss: 3.7184 - val_categorical_accuracy: 0.6621 - lr: 1.6000e-08
# Epoch 56/75
# 66/66 [==============================] - ETA: 0s - loss: 3.4240 - categorical_accuracy: 0.8189
# Epoch 00056: val_categorical_accuracy did not improve from 0.67126
#
# Epoch 00056: val_categorical_accuracy did not improve from 0.67126
#
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 3.1999999094978194e-09.
# 66/66 [==============================] - 63s 962ms/step - loss: 3.4240 - categorical_accuracy: 0.8189 - val_loss: 3.7184 - val_categorical_accuracy: 0.6621 - lr: 1.6000e-08
# Epoch 57/75
# 66/66 [==============================] - ETA: 0s - loss: 3.4206 - categorical_accuracy: 0.8269
# Epoch 00057: val_categorical_accuracy did not improve from 0.67126
#
# Epoch 00057: val_categorical_accuracy did not improve from 0.67126
# 66/66 [==============================] - 64s 973ms/step - loss: 3.4206 - categorical_accuracy: 0.8269 - val_loss: 3.7184 - val_categorical_accuracy: 0.6621 - lr: 3.2000e-09
# Epoch 58/75
# 66/66 [==============================] - ETA: 0s - loss: 3.4266 - categorical_accuracy: 0.8179
# Epoch 00058: val_categorical_accuracy did not improve from 0.67126
#
# Epoch 00058: val_categorical_accuracy did not improve from 0.67126
# 66/66 [==============================] - 65s 979ms/step - loss: 3.4266 - categorical_accuracy: 0.8179 - val_loss: 3.7184 - val_categorical_accuracy: 0.6621 - lr: 3.2000e-09
# Epoch 59/75
# 66/66 [==============================] - ETA: 0s - loss: 3.4289 - categorical_accuracy: 0.8179
# Epoch 00059: val_categorical_accuracy did not improve from 0.67126
#
# Epoch 00059: val_categorical_accuracy did not improve from 0.67126
# 66/66 [==============================] - 65s 989ms/step - loss: 3.4289 - categorical_accuracy: 0.8179 - val_loss: 3.7183 - val_categorical_accuracy: 0.6621 - lr: 3.2000e-09
# Epoch 60/75
# 66/66 [==============================] - ETA: 0s - loss: 3.4195 - categorical_accuracy: 0.8260
# Epoch 00060: val_categorical_accuracy did not improve from 0.67126
#
# Epoch 00060: val_categorical_accuracy did not improve from 0.67126
# 66/66 [==============================] - 64s 974ms/step - loss: 3.4195 - categorical_accuracy: 0.8260 - val_loss: 3.7183 - val_categorical_accuracy: 0.6621 - lr: 3.2000e-09
# Epoch 61/75
# 66/66 [==============================] - ETA: 0s - loss: 3.4368 - categorical_accuracy: 0.8118
# Epoch 00061: val_categorical_accuracy did not improve from 0.67126
#
# Epoch 00061: val_categorical_accuracy did not improve from 0.67126
#
# Epoch 00061: ReduceLROnPlateau reducing learning rate to 6.399999641359955e-10.
# 66/66 [==============================] - 65s 982ms/step - loss: 3.4368 - categorical_accuracy: 0.8118 - val_loss: 3.7183 - val_categorical_accuracy: 0.6621 - lr: 3.2000e-09
# Epoch 62/75
# 66/66 [==============================] - ETA: 0s - loss: 3.4338 - categorical_accuracy: 0.8250
# Epoch 00062: val_categorical_accuracy did not improve from 0.67126
#
# Epoch 00062: val_categorical_accuracy did not improve from 0.67126
# 66/66 [==============================] - 64s 975ms/step - loss: 3.4338 - categorical_accuracy: 0.8250 - val_loss: 3.7183 - val_categorical_accuracy: 0.6621 - lr: 6.4000e-10
# Epoch 63/75
# 66/66 [==============================] - ETA: 0s - loss: 3.4219 - categorical_accuracy: 0.8307
# Epoch 00063: val_categorical_accuracy did not improve from 0.67126
#
# Epoch 00063: val_categorical_accuracy did not improve from 0.67126
# 66/66 [==============================] - 64s 972ms/step - loss: 3.4219 - categorical_accuracy: 0.8307 - val_loss: 3.7183 - val_categorical_accuracy: 0.6621 - lr: 6.4000e-10
# Epoch 64/75
# 66/66 [==============================] - ETA: 0s - loss: 3.4247 - categorical_accuracy: 0.8279
# Epoch 00064: val_categorical_accuracy did not improve from 0.67126
#
# Epoch 00064: val_categorical_accuracy did not improve from 0.67126
# 66/66 [==============================] - 65s 983ms/step - loss: 3.4247 - categorical_accuracy: 0.8279 - val_loss: 3.7183 - val_categorical_accuracy: 0.6621 - lr: 6.4000e-10
# Epoch 65/75
# 66/66 [==============================] - ETA: 0s - loss: 3.4203 - categorical_accuracy: 0.8293
# Epoch 00065: val_categorical_accuracy did not improve from 0.67126
#
# Epoch 00065: val_categorical_accuracy did not improve from 0.67126
# 66/66 [==============================] - 63s 956ms/step - loss: 3.4203 - categorical_accuracy: 0.8293 - val_loss: 3.7183 - val_categorical_accuracy: 0.6621 - lr: 6.4000e-10
# Epoch 66/75
# 66/66 [==============================] - ETA: 0s - loss: 3.4184 - categorical_accuracy: 0.8246
# Epoch 00066: val_categorical_accuracy did not improve from 0.67126
#
# Epoch 00066: val_categorical_accuracy did not improve from 0.67126
#
# Epoch 00066: ReduceLROnPlateau reducing learning rate to 1.27999988386307e-10.
# 66/66 [==============================] - 63s 962ms/step - loss: 3.4184 - categorical_accuracy: 0.8246 - val_loss: 3.7183 - val_categorical_accuracy: 0.6621 - lr: 6.4000e-10
# Epoch 67/75
# 66/66 [==============================] - ETA: 0s - loss: 3.4255 - categorical_accuracy: 0.8236
# Epoch 00067: val_categorical_accuracy did not improve from 0.67126
#
# Epoch 00067: val_categorical_accuracy did not improve from 0.67126
# 66/66 [==============================] - 63s 956ms/step - loss: 3.4255 - categorical_accuracy: 0.8236 - val_loss: 3.7183 - val_categorical_accuracy: 0.6621 - lr: 1.2800e-10
# Epoch 68/75
# 66/66 [==============================] - ETA: 0s - loss: 3.4187 - categorical_accuracy: 0.8260
# Epoch 00068: val_categorical_accuracy did not improve from 0.67126
#
# Epoch 00068: val_categorical_accuracy did not improve from 0.67126
# 66/66 [==============================] - 63s 949ms/step - loss: 3.4187 - categorical_accuracy: 0.8260 - val_loss: 3.7183 - val_categorical_accuracy: 0.6621 - lr: 1.2800e-10
# Epoch 69/75
# 66/66 [==============================] - ETA: 0s - loss: 3.4204 - categorical_accuracy: 0.8269
# Epoch 00069: val_categorical_accuracy did not improve from 0.67126
#
# Epoch 00069: val_categorical_accuracy did not improve from 0.67126
# 66/66 [==============================] - 64s 968ms/step - loss: 3.4204 - categorical_accuracy: 0.8269 - val_loss: 3.7183 - val_categorical_accuracy: 0.6621 - lr: 1.2800e-10
# Epoch 70/75
# 66/66 [==============================] - ETA: 0s - loss: 3.4184 - categorical_accuracy: 0.8345
# Epoch 00070: val_categorical_accuracy did not improve from 0.67126
#
# Epoch 00070: val_categorical_accuracy did not improve from 0.67126
# 66/66 [==============================] - 64s 962ms/step - loss: 3.4184 - categorical_accuracy: 0.8345 - val_loss: 3.7183 - val_categorical_accuracy: 0.6621 - lr: 1.2800e-10
# Epoch 71/75
# 66/66 [==============================] - ETA: 0s - loss: 3.4205 - categorical_accuracy: 0.8388
# Epoch 00071: val_categorical_accuracy did not improve from 0.67126
#
# Epoch 00071: val_categorical_accuracy did not improve from 0.67126
#
# Epoch 00071: ReduceLROnPlateau reducing learning rate to 2.559999712214989e-11.
# 66/66 [==============================] - 64s 966ms/step - loss: 3.4205 - categorical_accuracy: 0.8388 - val_loss: 3.7183 - val_categorical_accuracy: 0.6621 - lr: 1.2800e-10
# Epoch 72/75
# 66/66 [==============================] - ETA: 0s - loss: 3.4304 - categorical_accuracy: 0.8198
# Epoch 00072: val_categorical_accuracy did not improve from 0.67126
#
# Epoch 00072: val_categorical_accuracy did not improve from 0.67126
# 66/66 [==============================] - 63s 953ms/step - loss: 3.4304 - categorical_accuracy: 0.8198 - val_loss: 3.7183 - val_categorical_accuracy: 0.6621 - lr: 2.5600e-11
# Epoch 73/75
# 66/66 [==============================] - ETA: 0s - loss: 3.4225 - categorical_accuracy: 0.8222
# Epoch 00073: val_categorical_accuracy did not improve from 0.67126
#
# Epoch 00073: val_categorical_accuracy did not improve from 0.67126
# 66/66 [==============================] - 63s 949ms/step - loss: 3.4225 - categorical_accuracy: 0.8222 - val_loss: 3.7183 - val_categorical_accuracy: 0.6621 - lr: 2.5600e-11
# Epoch 74/75
# 66/66 [==============================] - ETA: 0s - loss: 3.4302 - categorical_accuracy: 0.8260
# Epoch 00074: val_categorical_accuracy did not improve from 0.67126
#
# Epoch 00074: val_categorical_accuracy did not improve from 0.67126
# 66/66 [==============================] - 63s 952ms/step - loss: 3.4302 - categorical_accuracy: 0.8260 - val_loss: 3.7183 - val_categorical_accuracy: 0.6621 - lr: 2.5600e-11
# Epoch 75/75
# 66/66 [==============================] - ETA: 0s - loss: 3.4300 - categorical_accuracy: 0.8189
# Epoch 00075: val_categorical_accuracy did not improve from 0.67126
#
# Epoch 00075: val_categorical_accuracy did not improve from 0.67126
# 66/66 [==============================] - 65s 982ms/step - loss: 3.4300 - categorical_accuracy: 0.8189 - val_loss: 3.7183 - val_categorical_accuracy: 0.6621 - lr: 2.5600e-11

# %%
test_dataset = tf.data.TFRecordDataset(os.path.join(data_path, 'test.tfrecords'), compression_type='GZIP').map(decode).shuffle(100000).batch(batch_size)
results = model.evaluate(test_dataset)
# Out:
# 15/15 [==============================] - 2s 151ms/step - loss: 3.7125 - categorical_accuracy: 0.6119

# %%
def stats2(model):
   
# THis is for modify predicted test labels    
  def cf(x):
      x = np.asarray(x)
      y =[]
      for i in range(len(x)):
          max = np.argmax(x[i])
          y.append(max)
      return np.asarray(y)
  
  def load_test_dataset():
      i = 1
      data_path = '/content/drive/Shared drives/IML Project/Project/data/numpy_data'
      dataset = np.load(os.path.join(data_path, f'img_array_test_6k_{i}.npy'))
      while True:
          try:
              i += 1
              dataset = np.vstack((dataset, np.load(os.path.join(data_path, f'img_array_test_6k_{i}.npy'))))
          except FileNotFoundError:
              print(f'Loaded all test datasets')
              break
      # dataset = np.expand_dims(dataset, axis=1)
      for n in range(dataset.shape[0]):
          dataset[n, :, :] = dataset[n, :, :] / np.amax(dataset[n, :, :].flatten())
      print(f'Normalized {n+1} images')
      dataset = np.reshape(dataset, (-1, 62, 96, 96, 1))
      return dataset, np.eye(3)[labels[labels.train_valid_test == 2]['diagnosis'] - 1]

  labels = pd.read_csv('/content/drive/Shared drives/IML Project/Project/demographics.csv')
  test_data, test_labels = load_test_dataset()

  # Predicted Test labels
  predictions = model.predict(test_data)

  # Modified actual Test labels
  y_test = cf(test_labels)


  # Modified predicted test labels
  y_pred = cf(predictions)

  # Confusion Matrix
  conf = metrics.confusion_matrix(y_test, y_pred)

  accuracy = metrics.accuracy_score(y_test, y_pred)
  f1_score = metrics.f1_score(y_test, y_pred, average = None)
  recall = metrics.recall_score(y_test, y_pred, average= None)

  return accuracy, f1_score, recall

# %%
accuracy, f1_score, recall = stats2(model)
print("The accuracy is " + str(accuracy))
print("F1 Scores are " + str(f1_score))
print("Recall Scores are " + str(recall))
# Out:
# Loaded all test datasets
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: RuntimeWarning: invalid value encountered in true_divide
# Normalized 29078 images
# The accuracy is 0.6119402985074627
# F1 Scores are [0.73815461 0.33333333 0.66006601]
# Recall Scores are [0.93081761 0.24840764 0.65359477]

# %%
# def stats(test_dataset, model):
# # THis is for modify actual test labels
#     def df(t):
#         y =[]
#         for i in range(len(t)):
#             for j in range(len(t[i])):
#                 max = np.argmax(t[i][j])
#                 y.append(max)
#         return np.asarray(y)
    
# # THis is for modify predicted test labels    
#     def cf(x):
#         x = np.asarray(x)
#         y =[]
#         for i in range(len(x)):
#             max = np.argmax(x[i])
#             y.append(max)
#         return np.asarray(y)
    
# # THis is for extract actual test labels    
#     t = []
#     for image, label in test_dataset:
#         t.append(label)

# # Predicted Test labels
#     predictions = model.predict(test_dataset)

# # Modified actual Test labels
#     y_test = df(t)
  
    
# # Modified predicted test labels
#     y_pred = cf(predictions)
    
# # Confusion Matrix
#     conf = metrics.confusion_matrix(y_test, y_pred)

#     accuracy = metrics.accuracy_score(y_test, y_pred)
#     f1_score = metrics.f1_score(y_test, y_pred, average = None)
#     recall = metrics.recall_score(y_test, y_pred, average= None)
    
#     return accuracy, f1_score, recall
